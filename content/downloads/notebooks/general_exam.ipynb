# %% [markdown]
# While the standard tools for plotting in Python are great (`matplotlib`, `basemap`), I must admit I’ve been getting a bit bored.  In this post I am going to quickly show a few examples from some newer Python plotting libraries, many of which are built on top of `matplotlib`.
#
# We'll start with a quick rundown of a few libraries I'm aware of.  I know there are others but this is the list I'm going to look at.

# %% [markdown]
# #### Rundown of available plot libraries
# <table border=0 cellpadding=0 cellspacing=0 width=637 style='border-collapse:
#  collapse;table-layout:fixed;width:637pt'>
#  <col width=65 style='width:65pt'>
#  <col width=194 style='mso-width-source:userset;mso-width-alt:8277;width:194pt'>
#  <col width=66 style='mso-width-source:userset;mso-width-alt:2816;width:66pt'>
#  <col width=85 style='mso-width-source:userset;mso-width-alt:3626;width:85pt'>
#  <col width=51 style='mso-width-source:userset;mso-width-alt:2176;width:51pt'>
#  <col width=76 style='mso-width-source:userset;mso-width-alt:3242;width:76pt'>
#  <col width=60 style='mso-width-source:userset;mso-width-alt:2560;width:60pt'>
#  <col width=40 style='mso-width-source:userset;mso-width-alt:1706;width:40pt'>
#  <tr class=xl65 height=36 style='mso-height-source:userset;height:36.0pt'>
#   <td height=36 class=xl71 width=65 style='height:36.0pt;width:65pt'>Package</td>
#   <td class=xl71 width=194 style='border-left:none;width:194pt'>Description</td>
#   <td class=xl71 width=66 style='border-left:none;width:66pt'>Built On</td>
#   <td class=xl71 width=85 style='border-left:none;width:85pt'>Available in
#   Anaconda/Pypi</td>
#   <td class=xl71 width=51 style='border-left:none;width:51pt'>Python 3 Support</td>
#   <td class=xl71 width=76 style='border-left:none;width:76pt'>Includes Analysis
#   Tools</td>
#   <td class=xl71 width=60 style='border-left:none;width:60pt'>Interactive Plots</td>
#   <td class=xl71 width=40 style='border-left:none;width:40pt'>Spatial Maps</td>
#  </tr>
#  <tr height=75 style='height:75.0pt'>
#   <td height=75 class=xl66 style='height:75.0pt;border-top:none'><a
#   href="http://matplotlib.org/">matplotlib</a></td>
#   <td class=xl67 width=194 style='border-top:none;border-left:none;width:194pt'>matplotlib
#   is a python 2D plotting library which produces publication quality figures in
#   a variety of hardcopy formats and interactive environments across platforms.</td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python/C</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Both</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#  </tr>
#  <tr height=60 style='height:60.0pt'>
#   <td height=60 class=xl66 style='height:60.0pt;border-top:none'><a
#   href="http://pandas.pydata.org/">pandas</a></td>
#   <td class=xl69 width=194 style='border-top:none;border-left:none;width:194pt'>pandas<font
#   class="font0"><span style="mso-spacerun:yes">&nbsp;</span>is an open source,
#   BSD-licensed library providing high-performance, easy-to-use data structures
#   and data analysis tools</font></td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python
#   / C / Matplotlib</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Both</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#  </tr>
#  <tr height=60 style='height:60.0pt'>
#   <td height=60 class=xl66 style='height:60.0pt;border-top:none'><a
#   href="http://web.stanford.edu/~mwaskom/software/seaborn/index.html">seaborn</a></td>
#   <td class=xl67 width=194 style='border-top:none;border-left:none;width:194pt'>Seaborn
#   is a Python visualization library based on matplotlib. It provides a
#   high-level interface for drawing attractive statistical graphics.</td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python
#   / Matplotlib / Pandas</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Both</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Some</td>
#  </tr>
#  <tr height=45 style='height:45.0pt'>
#   <td height=45 class=xl66 style='height:45.0pt;border-top:none'><a
#   href="http://ggplot.yhathq.com/">ggplot</a></td>
#   <td class=xl70 width=194 style='border-top:none;border-left:none;width:194pt'>ggplot<font
#   class="font0"> is a plotting system for Python based on R's </font><font
#   class="font8">ggplot2</font><font class="font0"> and the </font><font
#   class="font7">Grammar of Graphics</font><font class="font0">.</font></td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python
#   / Matplotlib / Pandas</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Pypi Only</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#  </tr>
#  <tr height=60 style='height:60.0pt'>
#   <td height=60 class=xl66 style='height:60.0pt;border-top:none'><a
#   href="http://bokeh.pydata.org/">bokeh</a></td>
#   <td class=xl67 width=194 style='border-top:none;border-left:none;width:194pt'>Bokeh
#   is a Python interactive visualization library that targets modern web
#   browsers for presentation.</td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python
#   / JavaScript</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Both</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#  </tr>
#  <tr height=30 style='height:30.0pt'>
#   <td height=30 class=xl66 style='height:30.0pt;border-top:none'><a
#   href="https://plot.ly/python/">plotly</a></td>
#   <td class=xl67 width=194 style='border-top:none;border-left:none;width:194pt'>Plotl-python
#   api is an analytics and data visualization tool.</td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Pypi Only</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#  </tr>
#  <tr height=30 style='height:30.0pt'>
#   <td height=30 class=xl66 style='height:30.0pt;border-top:none'><a
#   href="http://vincent.readthedocs.org/en/latest/index.html">vincent</a></td>
#   <td class=xl67 width=194 style='border-top:none;border-left:none;width:194pt'>Vincent
#   allows you to build Vega specifications in a Pythonic way.</td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python
#   / JavaScript</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Pypi Only</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#  </tr>
#  <tr height=45 style='height:45.0pt'>
#   <td height=45 class=xl66 style='height:45.0pt;border-top:none'><a
#   href="http://matplotlib.org/basemap/index.html">basemap</a></td>
#   <td class=xl67 width=194 style='border-top:none;border-left:none;width:194pt'>The
#   matplotlib basemap toolkit is a library for plotting 2D data on maps in
#   Python.</td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python
#   / C / Matplotlib</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Both</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#  </tr>
#  <tr height=60 style='height:60.0pt'>
#   <td height=60 class=xl66 style='height:60.0pt;border-top:none'><a
#   href="http://scitools.org.uk/cartopy/docs/latest/index.html">cartopy</a></td>
#   <td class=xl67 width=194 style='border-top:none;border-left:none;width:194pt'>Cartopy
#   is a Python package designed to make drawing maps for data analysis and
#   visualisation as easy as possible.</td>
#   <td class=xl67 width=66 style='border-top:none;border-left:none;width:66pt'>Python
#   / C / Matplotlib</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Pypi Only</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>No</td>
#   <td class=xl68 style='border-top:none;border-left:none'>Yes</td>
#  </tr>
# </table>

# %% [markdown]
# Rather than just recreating examples from each of these projects, I figured I'd make an honest effort to use some real data and create some plots using each.  So for this post, I'll be using the [R-ArcticNET](http://www.r-arcticnet.sr.unh.edu/v4.0/index.html) streamflow database as an example dataset.
#
# Let's start by getting the data.  A bit of funny business but in the end, we get `Pandas DataFrame`s with all our `observations` and `attributes`.

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
print('matplotlib version %s' % mpl.__version__)
import pandas as pd
print('pandas version %s' % pd.__version__)
import seaborn as sns
print('seaborn version %s' % sns.__version__)
# import ggplot
# print('ggplot version %s' % ggplot.__version__)
# import bokeh as bk
# print('bokeh version %s' % bk.__version__)
# import vincent
# print('vincent version %s' % '0.4')
from mpl_toolkits.basemap import Basemap
print('Basemap version %s' % '1.0.7')

# vincent.core.initialize_notebook()
fontsize = 7
dpi = 200 # set to 900 for final publication
mpl.rc('font', family='sans-serif') 
mpl.rc('font', serif='Myriad Pro') 
mpl.rc('text', usetex='false') 
mpl.rcParams.update({'font.size': fontsize})
mpl.rcParams['mathtext.default'] = 'sf'
mpl.rcParams['pdf.fonttype'] = 42
# Out:
# matplotlib version 1.4.3
# pandas version 0.16.1
# seaborn version 0.6.dev
# Basemap version 1.0.7

# %%
from rasmlib.analysis.plotting import default_map, make_bmap, projections

# %%
import numpy as np
import datetime

def make_dates(years):
    '''make a monthly timeseries given a list of years'''
    dates = []
    for year in years:
        for month in range(1,13):
            dates.append(datetime.datetime(int(year), month, 1))
    return dates

# open attributes file
attributes = pd.read_csv('http://www.r-arcticnet.sr.unh.edu/v4.0/data/SiteAttributes.txt',
                   engine='python',
                   sep= '\t')

# open observations file
data = pd.read_csv('http://www.r-arcticnet.sr.unh.edu/v4.0/data/Discharge_ms.txt',
                   sep= '\t',
                   low_memory=False)

# Month names in observations file
_r_months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

data_series = {}
for i, point in enumerate(attributes['PointID']):
    name = str(attributes['Name'][i])
        
    inds = np.nonzero(data['Point_ID'] == point)[0]
    flow_table = np.empty((len(inds), len(_r_months)))

    for j, month in enumerate(_r_months):
        flow_table[:,j] = data[month][inds]

    times = make_dates(data['Year'][inds])

    data_series[name] = pd.Series(flow_table.flatten(), index=times)

observations = pd.DataFrame(data_series)

# %%
observations[:10].describe()
# Out:
#         Bol'shaya Shora At Shora   Iia (Verkhnyaya Iia) At Anikinskiy  \
# count                          0                                    0
# mean                         NaN                                  NaN
# std                          NaN                                  NaN
# min                          NaN                                  NaN
# 25%                          NaN                                  NaN
# 50%                          NaN                                  NaN
# 75%                          NaN                                  NaN
# max                          NaN                                  NaN
#
#        'K At 'K  ABITAU RIVER ABOVE CUMING LAKE  \
# count         0                               0
# mean        NaN                             NaN
# std         NaN                             NaN
# min         NaN                             NaN
# 25%         NaN                             NaN
# ...

# %% [markdown]
# Let's start by getting an understanding of where all our observations are at.  We'll make a scatter plot using the lat/lon information in the attributes.
#
# For this set of plots, we'll try to use these packages:
# - basemap
# - vincent
#
# ##Basemap

# %%
projections
# Out:
# {'wr50a': {'lat_0': 90,
#   'llcrnrlat': 16.53498636788452,
#   'llcrnrlon': 189.2229322311162,
#   'lon_0': -114,
#   'projection': 'lcc',
#   'rsphere': 6371200.0,
#   'urcrnrlat': 27.511827255753555,
#   'urcrnrlon': 16.90845094934209}}

# %%
# Basemap
scale_factor = 2000.
my_atts = attributes[['Long', 'Lat', 'DArea_effective', 'CountOfYear']].dropna()

fig, ax = plt.subplots(figsize=(12, 8))
# get the data that we'll put in the plot
lons = my_atts['Long'].values
lats = my_atts['Lat'].values
sizes = my_atts['DArea_effective'].values / scale_factor
cols = my_atts['CountOfYear'].values

# draw map with markers for float locations
m = Basemap(**projections['wr50a'])
x, y = m(lons, lats)
m.drawcoastlines(color='k', linewidth=0.75)
m.drawcountries()
m.fillcontinents(color='white', zorder=0)
m.drawmapboundary(fill_color='0.9')
m.drawparallels(np.arange(-80., 81., 20.))
m.drawmeridians(np.arange(-180., 181., 20.))

m.scatter(x, y, s=sizes, c=cols, marker="o", cmap='Blues', alpha=0.8, vmin=0, vmax=100)
plt.title('R-ArcticNET Streamflow Guages', fontsize=18)
cbar = m.colorbar(location='right', extend='max')
cbar.set_label('Years of Record')

sizes = [100, 500, 1000, 2000]
dots = [plt.scatter([],[], s=s, edgecolors='k', facecolor=None, alpha=0.8) for s in sizes]
labels = ["{:,}".format(int(s * scale_factor)) for s in sizes]

leg = plt.legend(dots, labels, ncol=1, frameon=False, fontsize=14,
                 handlelength=1, loc='lower left', labelspacing=1.8,
                 handletextpad=1.2, title='Basin Area (km$^{2}$)', scatterpoints=1, borderpad=1)
plt.setp(leg.get_title(),fontsize=16)
plt.savefig('r-arctic-net-locations.png', dpi=250)

# %% [markdown]
# ###Cartopy
# Cartopy offers the same functionality but since it doesn't support Python 3 yet, I'll just point you to an [example](http://nbviewer.ipython.org/gist/shoyer/16db9cd187886a3effd8).
#
# ###Vincent and Bokeh
# Both support plotting using projections but their support is still quite rudimentary.  Neither have much documentation in terms of how to use different projections or how to plot data other than shapefile-like sources.
#
#
# So moving on... let's take a look at what most of these libraries are best at.
# #Statistics
# Let's first look at the distributions of basin area vs. years of record.
#
# Let's make quick scatter plots using each of the following:
# - matplotlib
# - pandas
# - seaborn
# - ggplot
# - bokeh
# - vincent

# %%
fig, ax = plt.subplots()
ax.scatter(my_atts['CountOfYear'], my_atts['DArea_effective'], c='g', s=10, lw = 0)
ax.set_ylim([0, 3000000])
ax.set_xlim([0, 140])
ax.set_yscale('symlog')
ax.set_ylabel('Drainage Area')
ax.set_xlabel('Years of Record')
ax.set_title('r-ArcticNET Streamflow Guages', fontsize=18)

# %%
# Pandas is just using the standard matplotlib scatter + a bit of a wrapper
ax = my_atts.plot(kind='scatter', x='CountOfYear', y='DArea_effective',
                  ylim=[0, 3000000], xlim=[0, 140], c='g', lw=0, s=10)
ax.set_yscale('symlog')
ax.set_title('r-ArcticNET Streamflow Guages', fontsize=18)

# %%
df_ice = pd.read_csv('/Users/jhamman/Dropbox/general_exam/figures/seaice_september.csv')
df_ice.index = df_ice.year

# %%
df_snow = pd.read_csv('/Users/jhamman/Dropbox/general_exam/figures/snowcover.csv')

df_snow.extent /= 1000000
df_snow = df_snow[df_snow.month==6]
df_snow.index = df_snow.year
df_snow = df_snow[df_snow.year >= 1979]

# %%
ax = df_ice.extent.plot(label='Sea Ice Extent')
ax = df_snow.extent.plot(label='Snow Extent', ax=ax)
ax.legend()
plt.legend
# Out:
# <function matplotlib.pyplot.legend>

# %%
ice_color = "#34495e"
snow_color = "#2ecc71"
fontsize = 16

fig, ax = plt.subplots(figsize=(12, 8))

sns.regplot('year', 'extent', df_ice, scatter=False, line_kws={'color': ice_color}, ax=ax)
l1 = df_ice.extent.plot(color=ice_color, ax=ax, fontsize=fontsize)
sns.regplot('year', 'extent', df_snow, scatter=False, line_kws={'color': snow_color}, ax=ax)
l2 = df_snow.extent.plot(color=snow_color, ax=ax, fontsize=fontsize)
plt.xlim([1979,2015])
plt.ylim([3, 14])
plt.ylabel('Extent (millions square kilometers)', fontsize=fontsize)

plt.legend([l1.lines[0], l2.lines[2]], ['Sea Ice (September)', 'Snow (June)'], fontsize=fontsize)
ax.set_xlabel('')
plt.tight_layout()
fig.savefig('/Users/jhamman/Dropbox/general_exam/figures/snow_seaice_trends.pdf')
